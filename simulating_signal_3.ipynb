# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_signal

# %%
sampling_rate = 64
time = np.arange(-1, 2, 1/sampling_rate)
points = len(time)
noise = np.random.rand(points)

# %%
plot_signal(noise, sampling_rate=sampling_rate)
