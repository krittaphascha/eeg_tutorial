# %%
import pandas as pd
import neurokit2 as nk
import numpy as np
import matplotlib.pyplot as plt

# %%
ppg = nk.ppg_simulate(duration=10, sampling_rate=64, heart_rate=70)

signals, info = nk.ppg_process(ppg, sampling_rate=64)

# %%
plt.plot(signals['PPG_Clean'])

# %%
nk.ppg.ppg_segment(signals['PPG_Clean'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 nk.ppg.ppg_segment(signals['PPG_Clean'])
#
# AttributeError: module 'neurokit2.ppg' has no attribute 'ppg_segment'
